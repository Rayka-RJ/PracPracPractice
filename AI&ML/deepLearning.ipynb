# %%
import typing
import numpy as np

# %%
# Adam Optimizer

def adam_optimizer(parameter, grad, m, v, t, learning_rate=0.001, beta1=0.9, beta2=0.999,epsilon=1e-8):
    '''
    Adam optimizer
    '''
    pass
