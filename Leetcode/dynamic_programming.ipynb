# %%
import typing

# %% [markdown]
# ## Dynamic Programming
#
# knowledge

# %% [markdown]
# ## Leetcode - in numerical order

# %%
# 5. Longest Palindromic Substring

class Solution:
    def longestPalindrome(self, s: str) -> str:
        pass
