# %% [markdown]
# Tips:
#
# step1: SAVE the next
# step2: ADJUST the node
# step3: UPDATE the pointer
#
# Indexed problem: for loop to move
#
# GAP problem: two pointers

# %% [markdown]
# ## Preparation - to simulate the online leetcode environment

# %%
# Data Structure Preparation

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def createLinkedList(nums: list):
    if not nums:
        return None
    
    head = ListNode(nums[0])
    current = head

    for num in nums[1:]:
        current.next = ListNode(num)
        current = current.next

    return head

def printLinkedList(head):
    current = head
    while current:
        print(current.val, end = ' -> ')
        current = current.next
    print(None)

# %% [markdown]
# ## Leetcode - in numerical order

# %%
# 19. Remove Nth Node From End of List

class Solution:
    def removeNthFromEnd(self, head, n: int):
        pass

# %%
# 24. Swap Nodes in Pairs
class Solution:
    def swapPairs(self, head):
        pass

# %%
# 142. Linked List Cycle II

class Solution:
    def detectCycle(self, head):
        pass

# %%
# 160. Intersection of Two Linked Lists

class Solution:
    def getIntersectionNode(self, headA, headB):
        pass

# %%
# 203. Remove Linked List Elements

class Solution:
    def removeElements(self, head, val: int):
        pass

# %%
# 206. Reverse Linked List
class Solution:
    def reverseList(self, head):
        pass

# %%
# 707. Design Linked List

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class MyLinkedList:

    def __init__(self):
        pass
