# %%
from typing import List, Optional, Dict, Tuple

# %% [markdown]
# # Aim for Hard Leetcode
#
# Here is the hardest part of Leetcode

# %%
# 224. Basic Calculator
class Solution:
    def calculate(self, s: str) -> int:
        pass
