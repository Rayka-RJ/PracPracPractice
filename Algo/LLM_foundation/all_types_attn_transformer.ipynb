# %% [markdown]
# # To store all varients of transformer & attention

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### Self Attention

# %% [markdown]
# ### Causal Attention

# %% [markdown]
# ### Cross Attention

# %% [markdown]
# ### Back Propagation

# %% [markdown]
# ### Adam optimalizer
