# %% [markdown]
# # Day 27 - 2026/02/07
#
# ## 题目列表
# - 75. Sort Colors (Medium)
# - 41. First Missing Positive (Hard)
# - 112. Path Sum (Easy)
# - 994. Rotting Oranges (Medium)
# - 208. Implement Trie (Prefix Tree) (Medium)
#
# ## ⏱ 预计用时: 3-4小时

# %%
from typing import Optional, List
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def build_tree(values: List[Optional[int]]) -> Optional[TreeNode]:
    if not values:
        return None
    root = TreeNode(values[0])
    queue = deque([root])
    i = 1
    while queue and i < len(values):
        node = queue.popleft()
        if values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    return root

# %% [markdown]
# ## 75. Sort Colors (Medium)
#
# 给定一个包含红色、白色和蓝色、共 `n` 个元素的数组 `nums`，**原地**对它们进行排序，使得相同颜色的元素相邻，并按照红色、白色、蓝色顺序排列。
#
# 我们使用整数 `0`、`1` 和 `2` 分别表示红色、白色和蓝色。
#
# 必须在不使用库内置的 `sort` 函数的情况下解决这个问题。
#
# **Example 1:**
# - Input: `nums = [2,0,2,1,1,0]`
# - Output: `[0,0,1,1,2,2]`
#
# **Example 2:**
# - Input: `nums = [2,0,1]`
# - Output: `[0,1,2]`
#
# **Constraints:**
# - `n == nums.length`
# - `1 <= n <= 300`
# - `nums[i]` 为 `0`、`1` 或 `2`
#
# **进阶：**
# - 你能想出一个仅使用常数空间的一趟扫描算法吗？

# %%
class Solution:
    def solve_75(self, nums: List[int]) -> None:
        """原地对数组进行排序（0, 1, 2）。"""
        # TODO: 实现你的解法（原地修改 nums）
        pass

def test_solve_75():
    s = Solution()
    # 示例用例
    nums1 = [2,0,2,1,1,0]
    s.solve_75(nums1)
    assert nums1 == [0,0,1,1,2,2]
    
    nums2 = [2,0,1]
    s.solve_75(nums2)
    assert nums2 == [0,1,2]
    
    # 单元素
    nums3 = [0]
    s.solve_75(nums3)
    assert nums3 == [0]
    
    # 只有两种颜色
    nums4 = [2,2,1,1]
    s.solve_75(nums4)
    assert nums4 == [1,1,2,2]
    
    # 已排序
    nums5 = [0,1,2]
    s.solve_75(nums5)
    assert nums5 == [0,1,2]
    print("All test cases for 75 passed!")


test_solve_75()

# %% [markdown]
# ## 41. First Missing Positive (Hard)
#
# 给你一个未排序的整数数组 `nums`，请你找出其中没有出现的最小的正整数。
#
# 请你实现时间复杂度为 `O(n)` 并且只使用常数级别额外空间的解决方案。
#
# **Example 1:**
# - Input: `nums = [1,2,0]`
# - Output: `3`
#
# **Example 2:**
# - Input: `nums = [3,4,-1,1]`
# - Output: `2`
#
# **Example 3:**
# - Input: `nums = [7,8,9,11,12]`
# - Output: `1`
#
# **Constraints:**
# - `1 <= nums.length <= 10^5`
# - `-2^31 <= nums[i] <= 2^31 - 1`

# %%
class Solution:
    def solve_41(self, nums: List[int]) -> int:
        """返回数组中缺失的最小正整数。"""
        # TODO: 实现你的解法
        pass

def test_solve_41():
    s = Solution()
    # 示例用例
    assert s.solve_41([1,2,0]) == 3
    assert s.solve_41([3,4,-1,1]) == 2
    assert s.solve_41([7,8,9,11,12]) == 1
    
    # 单元素
    assert s.solve_41([1]) == 2
    assert s.solve_41([2]) == 1
    
    # 连续正整数
    assert s.solve_41([1,2,3]) == 4
    
    # 包含负数
    assert s.solve_41([-1,-2]) == 1
    print("All test cases for 41 passed!")


test_solve_41()

# %% [markdown]
# ## 112. Path Sum (Easy)
#
# 给你二叉树的根节点 `root` 和一个表示目标和的整数 `targetSum`。判断该树中是否存在**根节点到叶子节点**的路径，这条路径上所有节点值相加等于目标和 `targetSum`。如果存在，返回 `true`；否则，返回 `false`。
#
# **叶子节点**是指没有子节点的节点。
#
# **Example 1:**
# - Input: `root = [5,4,8,11,null,13,4,7,2,null,null,null,1]`, `targetSum = 22`
# - Output: `true`
# - 解释: 等于目标和的根节点到叶子节点路径如上图所示。
#
# **Example 2:**
# - Input: `root = [1,2,3]`, `targetSum = 5`
# - Output: `false`
# - 解释: 树中存在两条根节点到叶子节点的路径：`(1 --> 2): 和为 3`、`(1 --> 3): 和为 4`。不存在 `sum = 5` 的根节点到叶子节点路径。
#
# **Example 3:**
# - Input: `root = []`, `targetSum = 0`
# - Output: `false`
#
# **Constraints:**
# - 树中节点的数目在范围 `[0, 5000]` 内
# - `-1000 <= Node.val <= 1000`
# - `-1000 <= targetSum <= 1000`

# %%
class Solution:
    def solve_112(self, root: Optional[TreeNode], targetSum: int) -> bool:
        """判断是否存在根节点到叶子节点的路径，路径和等于 targetSum。"""
        # TODO: 实现你的解法
        pass

def test_solve_112():
    s = Solution()
    # 示例用例
    root1 = build_tree([5,4,8,11,None,13,4,7,2,None,None,None,1])
    assert s.solve_112(root1, 22) == True
    
    root2 = build_tree([1,2,3])
    assert s.solve_112(root2, 5) == False
    
    # 空树
    assert s.solve_112(None, 0) == False
    
    # 单节点
    root3 = build_tree([1])
    assert s.solve_112(root3, 1) == True
    assert s.solve_112(root3, 0) == False
    
    # 只有左子树
    root4 = build_tree([1,2])
    assert s.solve_112(root4, 3) == True
    print("All test cases for 112 passed!")


test_solve_112()

# %% [markdown]
# ## 994. Rotting Oranges (Medium)
#
# 在给定的 `m x n` 网格 `grid` 中，每个单元格可以有以下三个值之一：
#
# - 值 `0` 代表空单元格；
# - 值 `1` 代表新鲜橘子；
# - 值 `2` 代表腐烂的橘子。
#
# 每分钟，腐烂的橘子**周围 4 个方向上相邻**的新鲜橘子都会腐烂。
#
# 返回直到单元格中没有新鲜橘子为止所必须经过的最小分钟数。如果不可能，返回 `-1`。
#
# **Example 1:**
# - Input: `grid = [[2,1,1],[1,1,0],[0,1,1]]`
# - Output: `4`
#
# **Example 2:**
# - Input: `grid = [[2,1,1],[0,1,1],[1,0,1]]`
# - Output: `-1`
# - 解释: 左下角的橘子（第 2 行，第 0 列）永远不会腐烂，因为腐烂只会发生在 4 个正向上。
#
# **Example 3:**
# - Input: `grid = [[0,2]]`
# - Output: `0`
# - 解释: 因为 0 分钟时已经没有新鲜橘子了，所以答案就是 `0`。
#
# **Constraints:**
# - `m == grid.length`
# - `n == grid[i].length`
# - `1 <= m, n <= 10`
# - `grid[i][j]` 仅为 `0`、`1` 或 `2`

# %%
class Solution:
    def solve_994(self, grid: List[List[int]]) -> int:
        """返回所有橘子腐烂所需的最小分钟数。"""
        # TODO: 实现你的解法
        pass

def test_solve_994():
    s = Solution()
    # 示例用例
    assert s.solve_994([[2,1,1],[1,1,0],[0,1,1]]) == 4
    assert s.solve_994([[2,1,1],[0,1,1],[1,0,1]]) == -1
    assert s.solve_994([[0,2]]) == 0
    
    # 没有新鲜橘子
    assert s.solve_994([[2,2]]) == 0
    
    # 只有新鲜橘子
    assert s.solve_994([[1,1],[1,1]]) == -1
    
    # 单单元格
    assert s.solve_994([[2]]) == 0
    assert s.solve_994([[1]]) == -1
    print("All test cases for 994 passed!")


test_solve_994()

# %% [markdown]
# ## 208. Implement Trie (Prefix Tree) (Medium)
#
# **Trie**（发音类似 "try"）或者说**前缀树**是一种树形数据结构，用于高效地存储和检索字符串数据集中的键。这一数据结构有相当多的应用情景，例如自动补全和拼写检查。
#
# 请你实现 `Trie` 类：
#
# - `Trie()` 初始化前缀树对象。
# - `void insert(String word)` 向前缀树中插入字符串 `word`。
# - `boolean search(String word)` 如果字符串 `word` 在前缀树中，返回 `true`（即，在检索之前已经插入）；否则，返回 `false`。
# - `boolean startsWith(String prefix)` 如果之前已经插入的字符串 `word` 的前缀之一为 `prefix`，返回 `true`；否则，返回 `false`。
#
# **Example:**
# ```
# 输入
# ["Trie", "insert", "search", "search", "startsWith", "insert", "search"]
# [[], ["apple"], ["apple"], ["app"], ["app"], ["app"], ["app"]]
# 输出
# [null, null, true, false, true, null, true]
#
# 解释
# Trie trie = new Trie();
# trie.insert("apple");
# trie.search("apple");   // 返回 True
# trie.search("app");     // 返回 False
# trie.startsWith("app"); // 返回 True
# trie.insert("app");
# trie.search("app");     // 返回 True
# ```
#
# **Constraints:**
# - `1 <= word.length, prefix.length <= 2000`
# - `word` 和 `prefix` 仅由小写英文字母组成
# - `insert`、`search` 和 `startsWith` 调用次数**总计**不超过 `3 * 10^4` 次

# %%
class Trie:
    """前缀树（Trie）实现。"""
    
    def __init__(self):
        """初始化前缀树对象。"""
        # TODO: 实现你的初始化
        pass

    def insert(self, word: str) -> None:
        """向前缀树中插入字符串 word。"""
        # TODO: 实现你的插入方法
        pass

    def search(self, word: str) -> bool:
        """如果字符串 word 在前缀树中，返回 true；否则，返回 false。"""
        # TODO: 实现你的搜索方法
        pass

    def startsWith(self, prefix: str) -> bool:
        """如果之前插入的字符串 word 的前缀之一为 prefix，返回 true；否则，返回 false。"""
        # TODO: 实现你的前缀搜索方法
        pass

def test_solve_208():
    # 示例用例
    trie = Trie()
    trie.insert("apple")
    assert trie.search("apple") == True
    assert trie.search("app") == False
    assert trie.startsWith("app") == True
    trie.insert("app")
    assert trie.search("app") == True
    
    # 空字符串
    trie2 = Trie()
    trie2.insert("")
    assert trie2.search("") == True
    
    # 单字符
    trie3 = Trie()
    trie3.insert("a")
    assert trie3.search("a") == True
    assert trie3.startsWith("a") == True
    
    print("All test cases for 208 passed!")


test_solve_208()

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
