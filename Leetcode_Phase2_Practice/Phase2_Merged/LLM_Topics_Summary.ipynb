# %% [markdown]
# # LLM Topics 选学总结
#
# 本文件包含所有 LLM 相关选学主题。

# %% [markdown]
# ## 1. RAG深度 - Hybrid Search, Reranking
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 2. Chunking进阶 - Semantic Chunking
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 3. Embedding选型 - OpenAI vs Local (BGE, E5)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 4. Agent Memory Systems
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 5. Tool Use设计原则
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 6. Context Engineering
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 7. Function Calling深度
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 8. System Design Mock - RAG Pipeline
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 9. Agent架构设计
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 10. LangGraph State Machines
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 11. Multi-Agent Orchestration
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 12. Guardrails & Prompt Injection
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 13. LLM Evaluation
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 14. Fine-tuning (LoRA, QLoRA)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 15. Inference优化 (KV Cache, Quantization)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 16. 综合复习
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 17. RAG Architecture Overview
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 18. Chunking Strategies
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 19. Embedding Models (OpenAI, Cohere, Local models)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 20. Vector Databases (Pinecone, Milvus, Chroma)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 21. Prompt Engineering (Few-shot, CoT, Self-consistency)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 22. Context Window Management
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 23. Function Calling / Tool Use
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 24. Agent Architectures (ReAct, Plan-and-Execute, etc.)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 25. Multi-Agent Communication (你的SafeSieve论文相关)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 26. LangGraph vs AutoGen vs CrewAI
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 27. LLM Evaluation Metrics (BLEU, ROUGE, LLM-as-Judge)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 28. Guardrails & Safety (Prompt Injection防护)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 29. Memory in Agents (Short-term, Long-term, Episodic)
#
# (在这里记录你的学习笔记)

# %% [markdown]
# ## 30. Fine-tuning vs Prompting (When to use which)
#
# (在这里记录你的学习笔记)
