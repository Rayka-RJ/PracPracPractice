# %% [markdown]
# # Day 20 - 2026/01/31
#
# ## 题目列表
# - 74. Search a 2D Matrix (Medium)
# - 153. Find Minimum in Rotated Sorted Array (Medium)
# - 94. Binary Tree Inorder Traversal (Easy)
# - 98. Validate Binary Search Tree (Medium)
# - 101. Symmetric Tree (Easy)
#
# ## ⏱ 预计用时: 3-4小时

# %%
from typing import Optional, List
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def build_tree(values: List[Optional[int]]) -> Optional[TreeNode]:
    if not values:
        return None
    root = TreeNode(values[0])
    queue = deque([root])
    i = 1
    while queue and i < len(values):
        node = queue.popleft()
        if values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    return root

# %% [markdown]
# ## 74. Search a 2D Matrix (Medium)
#
# 给定一个 `m x n` 的整数矩阵 `matrix`，每一行从左到右升序排列，每一列从上到下升序排列，并且：
# - 每行的第一个整数大于前一行的最后一个整数。
#
# 给定一个整数 `target`，如果在矩阵中找到 `target`，返回 `True`，否则返回 `False`。
#
# **Example 1:**
# - Input: `matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]`, `target = 3`
# - Output: `True`
#
# **Example 2:**
# - Input: `matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]`, `target = 13`
# - Output: `False`
#
# **Constraints:**
# - `m == len(matrix)`
# - `n == len(matrix[i])`
# - `1 <= m, n <= 100`
# - `-10^4 <= matrix[i][j], target <= 10^4`

# %%
class Solution:
    def solve_74(self, matrix: List[List[int]], target: int) -> bool:
        """在二维矩阵中搜索目标值。"""
        # TODO: 实现你的解法（二分）
        pass


def test_solve_74():
    s = Solution()
    # 示例用例
    assert s.solve_74([[1,3,5,7],[10,11,16,20],[23,30,34,60]], 3) is True
    assert s.solve_74([[1,3,5,7],[10,11,16,20],[23,30,34,60]], 13) is False
    # 单行 / 单列
    assert s.solve_74([[1,2,3]], 2) is True
    assert s.solve_74([[1],[3],[5]], 4) is False
    print("All test cases for 74 passed!")


test_solve_74()

# %% [markdown]
# ## 153. Find Minimum in Rotated Sorted Array (Medium)
#
# 假设一个长度为 `n` 的升序排序数组在某个未知下标 `k` 处进行了旋转（`0 <= k < n`），例如：`[0,1,2,4,5,6,7]` 可能变为 `[4,5,6,7,0,1,2]`。
#
# 给定这样一个**无重复元素**的旋转排序数组 `nums`，请你找出数组中的最小元素。
#
# 你必须设计一个时间复杂度为 \(O(\log n)\) 的算法。
#
# **Example 1:**
# - Input: `nums = [3,4,5,1,2]`
# - Output: `1`
#
# **Example 2:**
# - Input: `nums = [4,5,6,7,0,1,2]`
# - Output: `0`
#
# **Constraints:**
# - `1 <= len(nums) <= 10^4`
# - `-10^4 <= nums[i] <= 10^4`

# %%
class Solution:
    def solve_153(self, nums: List[int]) -> int:
        """在旋转排序数组中找到最小元素。"""
        # TODO: 实现你的解法（二分）
        pass


def test_solve_153():
    s = Solution()
    # 示例用例
    assert s.solve_153([3,4,5,1,2]) == 1
    assert s.solve_153([4,5,6,7,0,1,2]) == 0
    # 未旋转
    assert s.solve_153([1,2,3,4]) == 1
    # 单元素
    assert s.solve_153([10]) == 10
    print("All test cases for 153 passed!")


test_solve_153()

# %% [markdown]
# ## 94. Binary Tree Inorder Traversal (Easy)
#
# 给定一个二叉树的根节点 `root`，返回它的**中序遍历**结果（`左 -> 根 -> 右`）。
#
# **Example:**
# - Input: `root = [1,null,2,3]`
# - Output: `[1,3,2]`
#
# **Constraints:**
# - 树中节点数在 `[0, 100]` 范围内
# - `-100 <= Node.val <= 100`

# %%
# 图结构就是很适合练习递归解法

class Solution:
    def solve_94(self, root: Optional[TreeNode]) -> List[int]:
        """返回二叉树的中序遍历结果。"""
        # TODO: 实现你的解法
        # 万事上来都应该先测试none
        if not root: return []
        left = self.solve_94(root.left)
        current = root.val
        right = self.solve_94(root.right)
        return left + [current] + right

def test_solve_94():
    s = Solution()
    # 示例用例
    root = build_tree([1,None,2,3])
    assert s.solve_94(root) == [1,3,2]
    # 空树
    assert s.solve_94(None) == []
    # 只有一个节点
    assert s.solve_94(build_tree([1])) == [1]
    print("All test cases for 94 passed!")


test_solve_94()
# Out:
# All test cases for 94 passed!

# %% [markdown]
# ## 98. Validate Binary Search Tree (Medium)
#
# 给定一个二叉树的根节点 `root`，判断它是否为**有效的二叉搜索树（BST）**。
#
# 有效的二叉搜索树定义如下：
# - 节点的左子树只包含小于当前节点值的节点；
# - 节点的右子树只包含大于当前节点值的节点；
# - 所有左子树和右子树都必须也是二叉搜索树。
#
# **Example 1:**
# - Input: `root = [2,1,3]`
# - Output: `True`
#
# **Example 2:**
# - Input: `root = [5,1,4,null,null,3,6]`
# - Output: `False`
#
# **Constraints:**
# - 树中节点数在 `[0, 10^4]` 范围内
# - `-2^31 <= Node.val <= 2^31 - 1`

# %%
class Solution:
    def solve_98(self, root: Optional[TreeNode]) -> bool:
        """判断一棵树是否为有效的二叉搜索树。"""
        # TODO: 实现你的解法（递归或中序遍历）
        pass


def test_solve_98():
    s = Solution()
    # 示例用例
    assert s.solve_98(build_tree([2,1,3])) is True
    assert s.solve_98(build_tree([5,1,4,None,None,3,6])) is False
    # 边界情况
    assert s.solve_98(None) is True
    assert s.solve_98(build_tree([1])) is True
    print("All test cases for 98 passed!")


test_solve_98()

# %% [markdown]
# ## 101. Symmetric Tree (Easy)
#
# 给定一个二叉树的根节点 `root`，检查它是否轴对称（即以中心为轴镜像对称）。
#
# **Example 1:**
# - Input: `root = [1,2,2,3,4,4,3]`
# - Output: `True`
#
# **Example 2:**
# - Input: `root = [1,2,2,None,3,None,3]`
# - Output: `False`
#
# **Constraints:**
# - 树中节点数在 `[0, 1000]` 范围内
# - `-100 <= Node.val <= 100`

# %%
class Solution:
    def solve_101(self, root: Optional[TreeNode]) -> bool:
        """判断二叉树是否轴对称。"""
        # TODO: 实现你的解法（递归或队列）
        pass


def test_solve_101():
    s = Solution()
    # 示例用例
    assert s.solve_101(build_tree([1,2,2,3,4,4,3])) is True
    assert s.solve_101(build_tree([1,2,2,None,3,None,3])) is False
    # 空树和单节点
    assert s.solve_101(None) is True
    assert s.solve_101(build_tree([1])) is True
    print("All test cases for 101 passed!")


test_solve_101()

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
