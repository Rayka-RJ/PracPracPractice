# %% [markdown]
# # Day 21 - 2026/02/01
#
# ## 题目列表
# - 105. Construct Binary Tree from Preorder and Inorder Traversal (Medium)
# - 236. Lowest Common Ancestor of a Binary Tree (Medium)
# - 124. Binary Tree Maximum Path Sum (Hard)
# - 114. Flatten Binary Tree to Linked List (Medium)
# - 199. Binary Tree Right Side View (Medium)
#
# ## ⏱ 预计用时: 3-4小时

# %%
from typing import Optional, List
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def build_tree(values: List[Optional[int]]) -> Optional[TreeNode]:
    if not values:
        return None
    root = TreeNode(values[0])
    queue = deque([root])
    i = 1
    while queue and i < len(values):
        node = queue.popleft()
        if values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    return root

# %% [markdown]
# ## 105. Construct Binary Tree from Preorder and Inorder Traversal (Medium)
#
# 给定两个整数数组 `preorder` 和 `inorder`，其中 `preorder` 是二叉树的**先序遍历**，`inorder` 是同一棵树的**中序遍历**，请构造并返回这棵二叉树。
#
# **Example 1:**
# - Input: `preorder = [3,9,20,15,7]`, `inorder = [9,3,15,20,7]`
# - Output: `[3,9,20,null,null,15,7]`
#
# **Example 2:**
# - Input: `preorder = [-1]`, `inorder = [-1]`
# - Output: `[-1]`
#
# **Constraints:**
# - `1 <= preorder.length <= 3000`
# - `inorder.length == preorder.length`
# - `-3000 <= preorder[i], inorder[i] <= 3000`
# - `preorder` 和 `inorder` 均**无重复**元素
# - `inorder` 均出现在 `preorder` 中
# - `preorder` **保证**为二叉树的前序遍历序列
# - `inorder` **保证**为二叉树的中序遍历序列

# %%
class Solution:
    def solve_105(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
        """根据先序遍历和中序遍历构造二叉树。"""
        # TODO: 实现你的解法（递归）
        pass


def test_solve_105():
    s = Solution()
    # 示例用例
    root1 = s.solve_105([3,9,20,15,7], [9,3,15,20,7])
    assert root1.val == 3
    assert root1.left.val == 9
    assert root1.right.val == 20
    
    root2 = s.solve_105([-1], [-1])
    assert root2.val == -1
    
    # 单节点
    root3 = s.solve_105([1], [1])
    assert root3.val == 1
    assert root3.left is None
    assert root3.right is None
    print("All test cases for 105 passed!")


test_solve_105()

# %% [markdown]
# ## 236. Lowest Common Ancestor of a Binary Tree (Medium)
#
# 给定一个二叉树，找到该树中两个指定节点的**最近公共祖先（LCA）**。
#
# 最近公共祖先的定义为：对于有根树 T 的两个节点 p、q，最近公共祖先表示为一个节点 x，满足 x 是 p、q 的祖先且 x 的深度尽可能大（**一个节点也可以是它自己的祖先**）。
#
# **Example 1:**
# - Input: `root = [3,5,1,6,2,0,8,null,null,7,4]`, `p = 5`, `q = 1`
# - Output: `3`
# - 解释: 节点 5 和节点 1 的最近公共祖先是节点 3。
#
# **Example 2:**
# - Input: `root = [3,5,1,6,2,0,8,null,null,7,4]`, `p = 5`, `q = 4`
# - Output: `5`
# - 解释: 节点 5 和节点 4 的最近公共祖先是节点 5。因为根据定义最近公共祖先节点可以为节点本身。
#
# **Constraints:**
# - 树中节点数在范围 `[2, 10^5]` 内
# - `-10^9 <= Node.val <= 10^9`
# - 所有 `Node.val` **互不相同**
# - `p != q`
# - `p` 和 `q` 均存在于给定的二叉树中

# %%
class Solution:
    def solve_236(self, root: Optional[TreeNode], p: Optional[TreeNode], q: Optional[TreeNode]) -> Optional[TreeNode]:
        """找到二叉树中两个节点的最近公共祖先。"""
        # TODO: 实现你的解法（递归）
        pass


def test_solve_236():
    s = Solution()
    # 示例用例
    root1 = build_tree([3,5,1,6,2,0,8,None,None,7,4])
    p1 = root1.left  # 5
    q1 = root1.right  # 1
    result1 = s.solve_236(root1, p1, q1)
    assert result1.val == 3
    
    root2 = build_tree([3,5,1,6,2,0,8,None,None,7,4])
    p2 = root2.left  # 5
    q2 = root2.left.right.right  # 4
    result2 = s.solve_236(root2, p2, q2)
    assert result2.val == 5
    
    # p 是 q 的祖先
    root3 = build_tree([1,2,3])
    p3 = root3
    q3 = root3.left
    result3 = s.solve_236(root3, p3, q3)
    assert result3.val == 1
    print("All test cases for 236 passed!")


test_solve_236()

# %% [markdown]
# ## 124. Binary Tree Maximum Path Sum (Hard)
#
# 二叉树中的**路径**被定义为一条从树中任意节点出发，沿父节点-子节点连接，达到任意节点的序列。同一个节点在一条路径序列中**至多出现一次**。该路径**至少包含一个节点**，且不一定经过根节点。
#
# **路径和**是路径中各节点值的总和。
#
# 给你一个二叉树的根节点 `root`，返回其**最大路径和**。
#
# **Example 1:**
# - Input: `root = [1,2,3]`
# - Output: `6`
# - 解释: 最优路径是 2 -> 1 -> 3，路径和为 2 + 1 + 3 = 6
#
# **Example 2:**
# - Input: `root = [-10,9,20,null,null,15,7]`
# - Output: `42`
# - 解释: 最优路径是 15 -> 20 -> 7，路径和为 15 + 20 + 7 = 42
#
# **Constraints:**
# - 树中节点数在范围 `[1, 3 * 10^4]` 内
# - `-1000 <= Node.val <= 1000`

# %%
class Solution:
    def solve_124(self, root: Optional[TreeNode]) -> int:
        """返回二叉树的最大路径和。"""
        # TODO: 实现你的解法（递归）
        pass


def test_solve_124():
    s = Solution()
    # 示例用例
    assert s.solve_124(build_tree([1,2,3])) == 6
    assert s.solve_124(build_tree([-10,9,20,None,None,15,7])) == 42
    
    # 单节点
    assert s.solve_124(build_tree([1])) == 1
    assert s.solve_124(build_tree([-3])) == -3
    
    # 全负数
    root = build_tree([-2,-1])
    assert s.solve_124(root) == -1
    print("All test cases for 124 passed!")


test_solve_124()

# %% [markdown]
# ## 114. Flatten Binary Tree to Linked List (Medium)
#
# 给你二叉树的根节点 `root`，请你将它展开为一个单链表：
#
# - 展开后的单链表应该同样使用 `TreeNode`，其中 `right` 子指针指向链表中下一个节点，而 `left` 子指针始终为 `None`。
# - 展开后的单链表应该与二叉树**先序遍历**顺序相同。
#
# **注意：** 你需要**原地**展开，不能使用额外的空间。
#
# **Example 1:**
# - Input: `root = [1,2,5,3,4,null,6]`
# - Output: `[1,null,2,null,3,null,4,null,5,null,6]`
#
# **Example 2:**
# - Input: `root = []`
# - Output: `[]`
#
# **Constraints:**
# - 树中节点数在范围 `[0, 2000]` 内
# - `-100 <= Node.val <= 100`

# %%
class Solution:
    def solve_114(self, root: Optional[TreeNode]) -> None:
        """将二叉树原地展开为链表（先序遍历顺序）。"""
        # TODO: 实现你的解法（递归或迭代）
        pass


def test_solve_114():
    s = Solution()
    # 示例用例
    root1 = build_tree([1,2,5,3,4,None,6])
    s.solve_114(root1)
    # 验证展开后的链表
    assert root1.val == 1
    assert root1.left is None
    assert root1.right.val == 2
    assert root1.right.right.val == 3
    
    # 空树
    root2 = None
    s.solve_114(root2)
    assert root2 is None
    
    # 单节点
    root3 = build_tree([1])
    s.solve_114(root3)
    assert root3.val == 1
    assert root3.left is None
    assert root3.right is None
    print("All test cases for 114 passed!")


test_solve_114()

# %% [markdown]
# ## 199. Binary Tree Right Side View (Medium)
#
# 给定一个二叉树的根节点 `root`，想象自己站在它的**右侧**，按照从顶部到底部的顺序，返回从右侧所能看到的节点值。
#
# **Example 1:**
# - Input: `root = [1,2,3,null,5,null,4]`
# - Output: `[1,3,4]`
#
# **Example 2:**
# - Input: `root = [1,null,3]`
# - Output: `[1,3]`
#
# **Example 3:**
# - Input: `root = []`
# - Output: `[]`
#
# **Constraints:**
# - 树中节点数在范围 `[0, 100]` 内
# - `-100 <= Node.val <= 100`

# %%
class Solution:
    def solve_199(self, root: Optional[TreeNode]) -> List[int]:
        """返回二叉树的右视图节点值列表。"""
        # TODO: 实现你的解法（BFS或DFS）
        pass


def test_solve_199():
    s = Solution()
    # 示例用例
    assert s.solve_199(build_tree([1,2,3,None,5,None,4])) == [1,3,4]
    assert s.solve_199(build_tree([1,None,3])) == [1,3]
    assert s.solve_199(None) == []
    
    # 单节点
    assert s.solve_199(build_tree([1])) == [1]
    
    # 只有左子树
    assert s.solve_199(build_tree([1,2])) == [1,2]
    print("All test cases for 199 passed!")


test_solve_199()

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
