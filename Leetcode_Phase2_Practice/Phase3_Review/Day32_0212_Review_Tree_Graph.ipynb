# %% [markdown]
# # Day 32 - 2026/02/12 - 复习: 树/图
#
# ## 题目列表
# - 112. Path Sum (Easy)
# - 994. Rotting Oranges (Medium)
# - 208. Implement Trie (Prefix Tree) (Medium)
# - 73. Set Matrix Zeroes (Medium)
#
# ## ⏱ 预计用时: 2-3小时

# %%
from typing import List, Optional

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
