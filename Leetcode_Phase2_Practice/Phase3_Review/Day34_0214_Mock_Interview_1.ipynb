# %%
"""
# Day 34 - 2026/02/14 - Mock Interview (一)

## 📋 模拟面试流程

### Part 1: Coding (45分钟)
从以下题目中随机选择3题，每题限时15分钟：
- 随机Easy: 1题
- 随机Medium: 2题

### Part 2: System Design (30分钟)
**设计题目**: Design a RAG-based Customer Support System

需要考虑的点:
- Document ingestion pipeline
- Chunking strategy
- Embedding model selection
- Vector database choice
- Retrieval & reranking
- Response generation
- Evaluation metrics

### Part 3: Behavioral (15分钟)
准备回答以下问题:
- Tell me about your SafeSieve project
- Describe a challenging technical problem you solved at ADVANCE.AI
- How do you prioritize tasks when facing multiple deadlines?

## 🎯 今日目标
- 完成完整模拟流程
- 记录时间和正确率
- 反思改进点
"""

# 随机抽题池
easy_pool = [1, 20, 21, 70, 94, 104, 121, 136, 206, 226]
medium_pool = [2, 3, 5, 11, 15, 33, 46, 48, 49, 53, 55, 56, 62, 75, 78, 79, 98, 102, 128, 139, 142, 146, 148, 152, 155, 198, 200, 207, 215, 238, 287, 300, 322, 347]

import random
print("Today's Problems:")
print(f"Easy: {random.choice(easy_pool)}")
print(f"Medium 1: {random.choice(medium_pool)}")
print(f"Medium 2: {random.choice(medium_pool)}")
