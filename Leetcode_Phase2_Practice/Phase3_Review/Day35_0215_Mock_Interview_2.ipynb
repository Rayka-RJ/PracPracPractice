# %%
"""
# Day 35 - 2026/02/15 - Mock Interview (二)

## 📋 模拟面试流程

### Part 1: Coding (45分钟)
从以下题目中随机选择3题，每题限时15分钟

### Part 2: System Design (30分钟)
**设计题目**: Design an AML Screening Agent System

基于你的实习经验，需要考虑:
- 3-layer filter architecture
- Entity matching strategy
- Context engineering for domain knowledge
- Human-in-the-loop design
- Cost optimization (你实现的75% cost reduction)
- Evaluation metrics

### Part 3: Deep Dive (15分钟)
准备深入讨论:
- SafeSieve的pruning算法细节
- 为什么选择0-extension clustering?
- 如何处理prompt injection attacks?
- A*STAR蛋白质设计项目的技术挑战

## 🎯 今日目标
- 完成完整模拟流程
- 确保能清晰解释所有项目细节
- 准备好开始投递!
"""
