# %% [markdown]
# # Day 30 - 2026/02/10 - DP + Graph + Greedy
#
# ## 题目列表
# - 207. Course Schedule (Medium)
# - 763. Partition Labels (Medium)
# - 45. Jump Game II (Medium)
# - 121. Best Time to Buy and Sell Stock (Easy)
#
# ## ⏱ 预计用时: 3-4小时
#
# ## 📚 LLM Topic (选学): 综合复习

# %%
from typing import List

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
