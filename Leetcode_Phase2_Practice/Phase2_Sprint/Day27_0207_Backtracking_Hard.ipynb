# %% [markdown]
# # Day 27 - 2026/02/07 - Backtracking 进阶
#
# ## 题目列表
# - 51. N-Queens (Hard)
# - 131. Palindrome Partitioning (Medium)
# - 77. Combinations (Medium)
#
# ## ⏱ 预计用时: 3-4小时
#
# ## 📚 LLM Topic (选学): LLM Evaluation

# %%
from typing import List

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
