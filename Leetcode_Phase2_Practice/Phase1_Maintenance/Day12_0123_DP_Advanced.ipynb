# %% [markdown]
# # Day 12 - 2026/01/23 - DP 进阶
#
# ## 题目列表
# - 300. Longest Increasing Subsequence (Medium)
# - 72. Edit Distance (Medium)

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 300. Longest Increasing Subsequence (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:
        # TODO: Implement your solution
        pass

# Test cases
def test_lengthOfLIS():
    s = Solution()
    assert s.lengthOfLIS([10,9,2,5,3,7,101,18]) == 4
    assert s.lengthOfLIS([0,1,0,3,2,3]) == 4
    assert s.lengthOfLIS([7,7,7,7,7,7,7]) == 1

    print("All test cases passed!")

test_lengthOfLIS()

# %% [markdown]
# ## 72. Edit Distance (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def minDistance(self, word1: str, word2: str) -> int:
        # TODO: Implement your solution
        pass

# Test cases
def test_minDistance():
    s = Solution()
    assert s.minDistance("horse", "ros") == 3
    assert s.minDistance("intention", "execution") == 5
    assert s.minDistance("", "") == 0

    print("All test cases passed!")

test_minDistance()

# %% [markdown]
# ## 📚 Today's LLM Topic: Guardrails & Safety (Prompt Injection防护)
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
