# %% [markdown]
# # Day 07 - 2026/01/18 - Binary Tree 基础
#
# ## 题目列表
# - 104. Maximum Depth of Binary Tree (Easy)
# - 102. Binary Tree Level Order Traversal (Medium)
#
# ## ⏱ 预计用时: 40分钟

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %%
from typing import List, Optional
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def build_tree(values: List[Optional[int]]) -> Optional[TreeNode]:
    """从列表构建二叉树，None表示空节点"""
    if not values:
        return None
    root = TreeNode(values[0])
    queue = deque([root])
    i = 1
    while queue and i < len(values):
        cur = queue.popleft()
        if values[i] is not None:
            cur.left = TreeNode(values[i])
            queue.append(cur.left)
        i += 1
        if i < len(values) and values[i] is not None:
            cur.right = TreeNode(values[i])
            queue.append(cur.right)
        i += 1
    return root

def tree_to_list(root: Optional[TreeNode]) -> List[Optional[int]]:
    """将二叉树转换为列表表示"""
    if not root:
        return []
    result = []
    queue = deque([root])
    while queue:
        node = queue.popleft()
        if node:
            result.append(node.val)
            queue.append(node.left)
            queue.append(node.right)
        else:
            result.append(None)
    while result and result[-1] is None:
        result.pop()
    return result

# %% [markdown]
# ## 102. Binary Tree Level Order Traversal (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
from collections import deque

class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        # TODO: Implement your solution
        if not root: return []
        queue = deque([root])
        res = []
        while queue:
            layer = []
            for _ in range(len(queue)):
                node = queue.popleft()
                layer.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            res.append(layer)
        return res

# Test cases
def test_levelOrder():
    s = Solution()
    root = build_tree([3,9,20,None,None,15,7])
    assert s.levelOrder(root) == [[3],[9,20],[15,7]]
    assert s.levelOrder(build_tree([])) == []
    assert s.levelOrder(build_tree([1])) == [[1]]

    print("All test cases passed!")

test_levelOrder()
# Out:
# All test cases passed!

# %% [markdown]
# ## 104. Maximum Depth of Binary Tree (Easy)
#
# 请在下方实现解法，并通过测试。

# %%
# all recursion
# 递归结构的写法，先写边界case，再写return，最后填充left/right的遍历方式
# recursion主要看事物的最小可拆分单元，以及树、子树的区别，子树也就是一个重复、小一点的树，找到二者的区别即是recursion要return的关键
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        # TODO: Implement your solution
        if not root: return 0
        left = self.maxDepth(root.left)
        right = self.maxDepth(root.right)
        return max(left, right) + 1

# Test cases
def test_maxDepth():
    s = Solution()
    root = build_tree([3,9,20,None,None,15,7])
    assert s.maxDepth(root) == 3
    assert s.maxDepth(build_tree([1])) == 1
    assert s.maxDepth(build_tree([])) == 0

    print("All test cases passed!")

test_maxDepth()
# Out:
# All test cases passed!

# %% [markdown]
# ## 📚 LLM Topic (选学笔记): Function Calling / Tool Use
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# 这个题是层序遍历，天然适合用队列（循环）
#
# 而递归更适合前序/中序/后序这类“遍历整棵树”问题。
#
# 如果题目需要一层层处理（比如 level order），用循环+队列更清晰；如果需要自上而下/自下而上递归分解，用recursion。
