# %% [markdown]
# # Day 06 - 2026/01/17 - Binary Search
#
# ## 题目列表
# - 33. Search in Rotated Sorted Array (Medium)
# - 34. Find First and Last Position of Element in Sorted Array (Medium)

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 33. Search in Rotated Sorted Array (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def search(self, nums: List[int], target: int) -> int:
        # TODO: Implement your solution
        pass

# Test cases
def test_search():
    s = Solution()
    assert s.search([4,5,6,7,0,1,2], 0) == 4
    assert s.search([4,5,6,7,0,1,2], 3) == -1
    assert s.search([1], 0) == -1

    print("All test cases passed!")

test_search()

# %% [markdown]
# ## 34. Find First and Last Position of Element in Sorted Array (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        # TODO: Implement your solution
        pass

# Test cases
def test_searchRange():
    s = Solution()
    assert s.searchRange([5,7,7,8,8,10], 8) == [3,4]
    assert s.searchRange([5,7,7,8,8,10], 6) == [-1,-1]
    assert s.searchRange([], 0) == [-1,-1]

    print("All test cases passed!")

test_searchRange()

# %% [markdown]
# ## 📚 Today's LLM Topic: Context Window Management
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
