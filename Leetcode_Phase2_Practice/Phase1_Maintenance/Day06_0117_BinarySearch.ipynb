# %% [markdown]
# # Day 06 - 2026/01/17 - Binary Search
#
# ## 题目列表
# - 33. Search in Rotated Sorted Array (Medium)
#
# ## ⏱ 预计用时: 30分钟

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 33. Search in Rotated Sorted Array (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
# 左右指针摇摆局
class Solution:
    def search(self, nums: List[int], target: int) -> int:
        # TODO: Implement your solution
        left, right = 0, len(nums)-1
        while left <= right:
            mid = (left+right)//2
            if nums[mid] == target:
                return mid
                # 以上都是做双指针search的必备代码
            
            # check 完mid之后，要收敛窗口
            # 优先比较条件更容易的部分，比如有序性，有序肯定比无序更好check，所以有序优先
            # 先check是否==mid，确定！=之后，区间就变成了[left, mid]和[mid+1, right+1]，不含mid
            if nums[left] <= nums[mid]:
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else:
                    left = mid + 1
            else:
                if nums[mid] < target <= nums[right]:
                    left = mid + 1
                else:
                    right = mid - 1
        return -1 

# Test cases
def test_search():
    s = Solution()
    assert s.search([4,5,6,7,0,1,2], 0) == 4
    assert s.search([4,5,6,7,0,1,2], 3) == -1
    assert s.search([1], 0) == -1

    print("All test cases passed!")

test_search()
# Out:
# All test cases passed!

# %% [markdown]
# ## 📚 LLM Topic (选学笔记): Context Window Management
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
