# %% [markdown]
# # Day 01 - 2026/01/12 - Hashtable
#
# ## 题目列表
# - 1. Two Sum (Easy)
# - 49. Group Anagrams (Medium)
#
# ## ⏱ 预计用时: 40分钟

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 1. Two Sum (Easy)
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        # TODO: Implement your solution
        check = {}
        for i, num in enumerate(nums):
            if target-num in check:            
                return [check[target-num], i]
            check[num] = i

# Test cases
def test_twoSum():
    s = Solution()
    assert s.twoSum([2,7,11,15], 9) == [0,1]
    assert s.twoSum([3,2,4], 6) == [1,2]
    assert s.twoSum([3,3], 6) == [0,1]

    print("All test cases passed!")

test_twoSum()
# Out:
# All test cases passed!

# %% [markdown]
# ## 49. Group Anagrams (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        # TODO: Implement your solution
        check = {}
        for str in strs:
            key = ''.join(sorted(str))
            check.setdefault(key,[]).append(str)
        
        return list(check.values())

# Test cases
def test_groupAnagrams():
    s = Solution()
    result = s.groupAnagrams(["eat","tea","tan","ate","nat","bat"])
    result_sorted = [sorted(group) for group in result]
    result_sorted.sort()
    expected = [['ate', 'eat', 'tea'], ['bat'], ['nat', 'tan']]
    assert result_sorted == expected
    assert s.groupAnagrams(["", ""]) == [["", ""]]
    assert s.groupAnagrams(["a"]) == [["a"]]

    print("All test cases passed!")

test_groupAnagrams()
# Out:
# All test cases passed!

# %% [markdown]
# ## 📚 LLM Topic (选学笔记): RAG Architecture Overview
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# 关于dict的一些语法：
#
# ```py
# from collection import defaultdict
# check = defaultdict(list)
#
# check[key] = check.get(key,[]) + [str]
# check.setdefault(key, []).append(str)
#
# list(check.items())
# list(check.keys())
# list(check.values())
#
# # 按某元素排序
# sorted(list_or_dict, key=lambda x:x[0])
# ```
