# %% [markdown]
# # Day 05 - 2026/01/16 - Stack
#
# ## 题目列表
# - 20. Valid Parentheses (Easy)
# - 84. Largest Rectangle in Histogram (Hard)

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 20. Valid Parentheses (Easy)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def isValid(self, s: str) -> bool:
        # TODO: Implement your solution
        pass

# Test cases
def test_isValid():
    s = Solution()
    assert s.isValid("()") is True
    assert s.isValid("()[]{}") is True
    assert s.isValid("(]") is False
    assert s.isValid("(())") is True

    print("All test cases passed!")

test_isValid()

# %% [markdown]
# ## 84. Largest Rectangle in Histogram (Hard)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:
        # TODO: Implement your solution
        pass

# Test cases
def test_largestRectangleArea():
    s = Solution()
    assert s.largestRectangleArea([2,1,5,6,2,3]) == 10
    assert s.largestRectangleArea([2,4]) == 4
    assert s.largestRectangleArea([1]) == 1

    print("All test cases passed!")

test_largestRectangleArea()

# %% [markdown]
# ## 📚 Today's LLM Topic: Prompt Engineering (Few-shot, CoT, Self-consistency)
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
