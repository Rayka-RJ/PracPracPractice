# %% [markdown]
# # Day 12 - 2026/01/23 - DP 进阶
#
# ## 题目列表
# - 198. House Robber (Medium)
#
# ## ⏱ 预计用时: 30分钟

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 198. House Robber (Medium)
#
# You are a professional robber planning to rob houses along a street.
# Each house has a certain amount of money stashed.
# Adjacent houses have security systems connected - if two adjacent houses were broken into on the same night, it will automatically contact the police.
#
# Given an integer array nums representing the amount of money of each house,
# return the maximum amount of money you can rob tonight without alerting the police.
#
# **Example:**
# - Input: nums = [1,2,3,1]
# - Output: 4 (Rob house 1 and 3: 1 + 3 = 4)

# %%
# 经典的house robber，使用dp即可记录，每个dp记录到这个位置时最大数值
# 每个dp位置可更新的在于：抢or不抢，如果不抢，那就是dp[-1]，如果抢，那就是dp[-2]+current

class Solution:
    def rob(self, nums: List[int]) -> int:
        # TODO: Implement your solution
        if len(nums) <= 2: return max(nums)
        dp = [0] * len(nums)
        dp[0] = nums[0]
        dp[1] = max(nums[0], nums[1])
        for i in range(2, len(nums)):
            dp[i] = max(dp[i-1], dp[i-2]+nums[i])
        return max(dp)

# Test cases
def test_rob():
    s = Solution()
    assert s.rob([1,2,3,1]) == 4
    assert s.rob([2,7,9,3,1]) == 12
    assert s.rob([2,1,1,2]) == 4
    print("All test cases passed!")

test_rob()
# Out:
# All test cases passed!

# %% [markdown]
# ## 📚 LLM Topic (选学笔记): Guardrails & Safety (Prompt Injection防护)
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
