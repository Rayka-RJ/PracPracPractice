# %% [markdown]
# # Day 14 - 2026/01/25 - Greedy
#
# ## 题目列表
# - 55. Jump Game (Medium)
#
# ## ⏱ 预计用时: 30分钟

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 55. Jump Game (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
# jump game，经典greedy，每个idx代表能跳出的最大距离
# 所以从0开始，每到一个idx，就可以遍历下面所有可能到达的idx，然后找出最远的那个，直到能超过len(nums)
# 维护一个farthest，每次遍历可能的最大值：
# - 如果farthest超过了末尾，就True
# - 如果i都大于farthest了，说明就不可能达到了

class Solution:
    def canJump(self, nums: List[int]) -> bool:
        # TODO: Implement your solution
        farthest = 0
        for i in range(len(nums)):
            if i > farthest:
                return False
            farthest = max(farthest, i+nums[i])
            if farthest >= len(nums)-1:
                return True


# 这道题经典地要注意idx和value的互相表达含义
# 注意比较顺序：先看i是不是超过了far，能不能达到i，再看到了i之后能不能越过最后边界

# Test cases
def test_canJump():
    s = Solution()
    assert s.canJump([2,3,1,1,4]) is True
    assert s.canJump([3,2,1,0,4]) is False
    assert s.canJump([0]) is True

    print("All test cases passed!")

test_canJump()
# Out:
# All test cases passed!

# %% [markdown]
# ## 📚 LLM Topic (选学笔记): Fine-tuning vs Prompting (When to use which)
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
