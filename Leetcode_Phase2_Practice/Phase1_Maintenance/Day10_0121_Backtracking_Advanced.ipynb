# %% [markdown]
# # Day 10 - 2026/01/21 - Backtracking 进阶
#
# ## 题目列表
# - 39. Combination Sum (Medium)
# - 79. Word Search (Medium)

# %%
from typing import List, Dict, Tuple, Optional
from collections import defaultdict, deque, Counter
import heapq

# %% [markdown]
# ## 39. Combination Sum (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        # TODO: Implement your solution
        pass

# Test cases
def test_combinationSum():
    s = Solution()
    result = s.combinationSum([2,3,6,7], 7)
    expected = sorted([sorted(x) for x in [[2,2,3],[7]]])
    assert sorted([sorted(x) for x in result]) == expected
    assert s.combinationSum([2], 1) == []
    assert s.combinationSum([2,3,5], 8) is not None

    print("All test cases passed!")

test_combinationSum()

# %% [markdown]
# ## 79. Word Search (Medium)
#
# 请在下方实现解法，并通过测试。

# %%
class Solution:
    def exist(self, board: List[List[str]], word: str) -> bool:
        # TODO: Implement your solution
        pass

# Test cases
def test_exist():
    s = Solution()
    board = [["A","B","C","E"],["S","F","C","S"],["A","D","E","E"]]
    assert s.exist(board, "ABCCED") is True
    assert s.exist(board, "SEE") is True
    assert s.exist(board, "ABCB") is False

    print("All test cases passed!")

test_exist()

# %% [markdown]
# ## 📚 Today's LLM Topic: LangGraph vs AutoGen vs CrewAI
#
# ### Key Questions:
# - What are the核心概念?
# - 关键应用场景有哪些?
# - 与其他方法相比的优势和限制是什么?

# %% [markdown]
# ## 📝 Notes
#
# (在这里记录你的学习笔记)
